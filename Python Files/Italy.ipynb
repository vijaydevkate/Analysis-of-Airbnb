# %% [markdown]
# * **Mounting the Drive**

# %%
# Mounting the Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **1. Importing the Required Modules**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### **2. Importing the Dataset**

# %%
df=pd.read_csv('http://data.insideairbnb.com/uconn/msbapm/capstone/2022/fall/listings-italy-2022-08.csv.gz', compression='gzip')

# %% [markdown]
# * **Printing the First 5 Rows of the Dataset**

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  35899613  https://www.airbnb.com/rooms/35899613  20220802215029
# 1  51419337  https://www.airbnb.com/rooms/51419337  20220802215029
# 2    907887    https://www.airbnb.com/rooms/907887  20220802215029
# 3    610985    https://www.airbnb.com/rooms/610985  20220802215029
# 4  53407778  https://www.airbnb.com/rooms/53407778  20220802215029
#
#   last_searched last_scraped  \
# 0           NaN   2022-08-06
# 1    2022-08-03   2022-08-06
# 2    2022-08-03   2022-08-06
# 3    2022-08-03   2022-08-06
# 4    2022-08-03   2022-08-06
#
#                                                 name  \
# 0                                   Cosy Design Flat
# 1                                Casa Vacanze di Ro'
# 2                       Butterfly apt Navigli Milano
# 3          Centre Florence  beautiful 1500 apartment
# 4  Barbaroux Duplex al Quadrilatero by Wonderful ...
#
#                                          description  \
# 0  Un must! Il vantaggio di  70mq  luminosi e cur...
# 1  Casa Vacanze di Ro' è uno spazio indipendente,...
# 2  Idyllic flat for couple/one person, bright, ca...
# 3  Charming  apartment for two to four people, wi...
# 4  Tastefully renovated apartment in one of the a...
#
#                                neighborhood_overview  \
# 0  A 10 minuti a piedi da piazzale Loreto e dalla...
# 1                                                NaN
# 2  the Navigli area is the cultural center of Mil...
# 3  The central location and charming accomodation...
# 4  The wonderful city of Turin, capital of Piedmo...
#
#                                          picture_url    host_id  \
# 0  https://a0.muscache.com/pictures/pro_photo_too...  270018204
# 1  https://a0.muscache.com/pictures/miso/Hosting-...  416444264
# 2  https://a0.muscache.com/pictures/13254283/e422...    4863760
# 3  https://a0.muscache.com/pictures/miso/Hosting-...    3029201
# 4  https://a0.muscache.com/pictures/prohost-api/H...   13036400
#
#                                       host_url        host_name  host_since  \
# 0  https://www.airbnb.com/users/show/270018204          Massimo  2019-06-20
# 1  https://www.airbnb.com/users/show/416444264       Rosa Maria  2021-08-02
# 2    https://www.airbnb.com/users/show/4863760          Sabrina  2013-01-27
# 3    https://www.airbnb.com/users/show/3029201         Cristina  2012-07-23
# 4   https://www.airbnb.com/users/show/13036400  Wonderful Italy  2014-03-11
#
#         host_location                                         host_about  \
# 0        Milan, Italy  Ciao, milanese di nascita, da piccolo ho abita...
# 1                 NaN                                                NaN
# 2  Pietrasanta, Italy  Hello, my name is Sabrina, i'm a life lover an...
# 3     Florence, Italy  Here is my profile for Airbnb.\nHello, my name...
# 4        Milan, Italy  Siamo Wonderful Italy, abbiamo l'obiettivo di ...
#
#    host_response_time host_response_rate host_acceptance_rate  \
# 0                 NaN                NaN                  NaN
# 1                 NaN                NaN                  NaN
# 2  within a few hours                86%                   0%
# 3      within an hour               100%                  97%
# 4      within an hour                96%                  99%
#
#   host_is_superhost                                 host_thumbnail_url  \
# 0                 f  https://a0.muscache.com/im/pictures/user/bb01b...
# 1                 f  https://a0.muscache.com/im/pictures/user/d4d73...
# 2               NaN  https://a0.muscache.com/im/pictures/user/640a3...
# 3                 f  https://a0.muscache.com/im/users/3029201/profi...
# 4               NaN  https://a0.muscache.com/im/pictures/user/c4a92...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/user/bb01b...             Zona 3
# 1  https://a0.muscache.com/im/pictures/user/d4d73...                NaN
# 2  https://a0.muscache.com/im/pictures/user/640a3...             Zona 5
# 3  https://a0.muscache.com/im/users/3029201/profi...       SS.Annuziata
# 4  https://a0.muscache.com/im/pictures/user/c4a92...                NaN
#
#    host_listings_count  host_total_listings_count  \
# 0                  2.0                        2.0
# 1                  1.0                        1.0
# 2                  2.0                        4.0
# 3                  1.0                        3.0
# 4               1084.0                     1428.0
#
#                  host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'work_email']                    t
# 1                ['email', 'phone']                    t
# 2                ['email', 'phone']                    t
# 3                ['email', 'phone']                    t
# 4  ['email', 'phone', 'work_email']                    t
#
#   host_identity_verified             neighbourhood   latitude  longitude  \
# 0                      t  Milano, Lombardia, Italy  45.486160   9.227610
# 1                      t                       NaN  38.193390  13.327590
# 2                      f    Milan, Lombardy, Italy  45.445450   9.179140
# 3                      t  Florence, Tuscany, Italy  43.779110  11.263760
# 4                      t   Torino, Piemonte, Italy  45.071274   7.682794
#
#         property_type        room_type  accommodates  bathrooms  \
# 0  Entire rental unit  Entire home/apt             4        NaN
# 1  Entire guest suite  Entire home/apt             2        NaN
# 2  Entire rental unit  Entire home/apt             3        NaN
# 3  Entire rental unit  Entire home/apt             6        NaN
# 4  Entire rental unit  Entire home/apt             4        NaN
#
#   bathrooms_text  bedrooms  beds  \
# 0         1 bath       1.0   2.0
# 1         1 bath       1.0   1.0
# 2         1 bath       3.0   2.0
# 3      1.5 baths       2.0   3.0
# 4         1 bath       1.0   3.0
#
#                                            amenities    price  minimum_nights  \
# 0  ["Carbon monoxide alarm", "Fire extinguisher",...  $200.00               2
# 1  ["Hot water", "Outdoor shower", "Mosquito net"...  $139.00               2
# 2  ["Hair dryer", "Kitchen", "TV", "Heating", "Ai...   $78.00               3
# 3  ["Hot water", "Washer", "Bed linens", "Paid pa...  $132.00               3
# 4  ["Hot water", "Washer", "Bed linens", "Hot wat...   $73.00               1
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0              28                     2.0                     2.0
# 1              45                     2.0                     2.0
# 2              60                     3.0                     3.0
# 3              29                     2.0                     3.0
# 4            1125                     1.0                     5.0
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                    28.0                    28.0                     2.0
# 1                  1125.0                  1125.0                     2.0
# 2                    60.0                    60.0                     3.0
# 3                    28.0                  1125.0                     2.9
# 4                     2.0                  1125.0                     3.3
#
#    maximum_nights_avg_ntm  calendar_updated has_availability  availability_30  \
# 0                    28.0               NaN                t                0
# 1                  1125.0               NaN                t                8
# 2                    60.0               NaN                t                1
# 3                   688.2               NaN                t               19
# 4                   298.8               NaN                t               14
#
#    availability_60  availability_90  availability_365 calendar_last_scraped  \
# 0                0                0                 0            2022-08-06
# 1               33               63               338            2022-08-06
# 2                1                2                 2            2022-08-06
# 3               29               59               334            2022-08-06
# 4               44               74               283            2022-08-06
#
#    number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                 14                      0                       0
# 1                  0                      0                       0
# 2                  3                      0                       0
# 3                181                     15                       2
# 4                  5                      5                       1
#
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0   2019-08-27  2020-02-21                  4.86                    4.79
# 1          NaN         NaN                   NaN                     NaN
# 2   2013-04-08  2014-05-12                  4.00                    3.67
# 3   2012-09-30  2022-07-24                  4.78                    4.82
# 4   2021-12-30  2022-07-23                  4.60                    4.60
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       4.86                   4.57
# 1                        NaN                    NaN
# 2                       4.00                   3.67
# 3                       4.84                   4.86
# 4                       5.00                   4.80
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.86                    4.79                 4.71
# 1                          NaN                     NaN                  NaN
# 2                         4.00                    4.00                 4.00
# 3                         4.86                    4.84                 4.75
# 4                         5.00                    5.00                 4.60
#
#    requires_license      license instant_bookable  \
# 0               NaN          NaN                f
# 1               NaN          NaN                f
# 2               NaN          NaN                f
# 3               NaN          NaN                t
# 4               NaN  00127201480                t
#
#    calculated_host_listings_count  \
# 0                               2
# 1                               1
# 2                               2
# 3                               1
# 4                            1040
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            2
# 1                                            1
# 2                                            2
# 3                                            1
# 4                                          998
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                            42
#
#    calculated_host_listings_count_shared_rooms  region_id region_name  \
# 0                                            0      15146      Milano
# 1                                            0      82053     Palermo
# 2                                            0      15146      Milano
# 3                                            0      48017     Firenze
# 4                                            0       1272      Torino
#
#    region_parent_id region_parent_name  region_parent_parent_id  \
# 0                15             Milano                        3
# 1                82            Palermo                       19
# 2                15             Milano                        3
# 3                48            Firenze                        9
# 4                 1             Torino                        1
#
#   region_parent_parent_name  reviews_per_month
# 0                 Lombardia               0.39
# 1                   Sicilia                NaN
# 2                 Lombardia               0.03
# 3                   Toscana               1.51
# 4                  Piemonte               0.68

# %% [markdown]
# * **Summary of the Dataset**

# %%
# Summary
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440305 entries, 0 to 440304
# Data columns (total 80 columns):
#  #   Column                                        Non-Null Count   Dtype
# ---  ------                                        --------------   -----
#  0   id                                            440305 non-null  int64
#  1   listing_url                                   440305 non-null  object
#  2   scrape_id                                     440305 non-null  int64
#  3   last_searched                                 426853 non-null  object
#  4   last_scraped                                  440305 non-null  object
#  5   name                                          440267 non-null  object
#  6   description                                   432239 non-null  object
#  7   neighborhood_overview                         224385 non-null  object
#  8   picture_url                                   440219 non-null  object
#  9   host_id                                       440305 non-null  int64
#  10  host_url                                      440305 non-null  object
#  11  host_name                                     439333 non-null  object
#  12  host_since                                    439333 non-null  object
#  13  host_location                                 317026 non-null  object
#  14  host_about                                    205309 non-null  object
#  15  host_response_time                            386815 non-null  object
#  16  host_response_rate                            386815 non-null  object
#  17  host_acceptance_rate                          395446 non-null  object
#  18  host_is_superhost                             82779 non-null   object
#  19  host_thumbnail_url                            439333 non-null  object
#  20  host_picture_url                              439333 non-null  object
#  21  host_neighbourhood                            58346 non-null   object
#  22  host_listings_count                           439333 non-null  float64
#  23  host_total_listings_count                     439333 non-null  float64
#  24  host_verifications                            440305 non-null  object
#  25  host_has_profile_pic                          439333 non-null  object
#  26  host_identity_verified                        439333 non-null  object
#  27  neighbourhood                                 224385 non-null  object
#  28  latitude                                      440305 non-null  float64
#  29  longitude                                     440305 non-null  float64
#  30  property_type                                 440305 non-null  object
#  31  room_type                                     440305 non-null  object
#  32  accommodates                                  440305 non-null  int64
#  33  bathrooms                                     0 non-null       float64
#  34  bathrooms_text                                439633 non-null  object
#  35  bedrooms                                      427303 non-null  float64
#  36  beds                                          435157 non-null  float64
#  37  amenities                                     440305 non-null  object
#  38  price                                         440305 non-null  object
#  39  minimum_nights                                440305 non-null  int64
#  40  maximum_nights                                440305 non-null  int64
#  41  minimum_minimum_nights                        440302 non-null  float64
#  42  maximum_minimum_nights                        440302 non-null  float64
#  43  minimum_maximum_nights                        440302 non-null  float64
#  44  maximum_maximum_nights                        440302 non-null  float64
#  45  minimum_nights_avg_ntm                        440302 non-null  float64
#  46  maximum_nights_avg_ntm                        440302 non-null  float64
#  47  calendar_updated                              0 non-null       float64
#  48  has_availability                              440305 non-null  object
#  49  availability_30                               440305 non-null  int64
#  50  availability_60                               440305 non-null  int64
#  51  availability_90                               440305 non-null  int64
#  52  availability_365                              440305 non-null  int64
#  53  calendar_last_scraped                         440305 non-null  object
#  54  number_of_reviews                             440305 non-null  int64
#  55  number_of_reviews_ltm                         440305 non-null  int64
#  56  number_of_reviews_l30d                        440305 non-null  int64
#  57  first_review                                  323827 non-null  object
#  58  last_review                                   323827 non-null  object
#  59  review_scores_rating                          323827 non-null  float64
#  60  review_scores_accuracy                        321224 non-null  float64
#  61  review_scores_cleanliness                     321245 non-null  float64
#  62  review_scores_checkin                         321159 non-null  float64
#  63  review_scores_communication                   321200 non-null  float64
#  64  review_scores_location                        321147 non-null  float64
#  65  review_scores_value                           321139 non-null  float64
#  66  requires_license                              0 non-null       float64
#  67  license                                       47916 non-null   object
#  68  instant_bookable                              440305 non-null  object
#  69  calculated_host_listings_count                440305 non-null  int64
#  70  calculated_host_listings_count_entire_homes   440305 non-null  int64
#  71  calculated_host_listings_count_private_rooms  440305 non-null  int64
#  72  calculated_host_listings_count_shared_rooms   440305 non-null  int64
#  73  region_id                                     440305 non-null  int64
#  74  region_name                                   440305 non-null  object
#  75  region_parent_id                              440305 non-null  int64
#  76  region_parent_name                            440305 non-null  object
#  77  region_parent_parent_id                       440305 non-null  int64
#  78  region_parent_parent_name                     440305 non-null  object
#  79  reviews_per_month                             323827 non-null  float64
# dtypes: float64(23), int64(20), object(37)
# memory usage: 268.7+ MB

# %% [markdown]
# ##  **3. Data Preprocessing**

# %% [markdown]
# ### **3.1 Exploring Missing Values**

# %%
print("Number of Missing Values (Columnwise) :\n")
pd. set_option('display.max_rows', 500)
df.isna().sum()
# Out:
# Number of Missing Values (Columnwise) :
# id                                                   0
# listing_url                                          0
# scrape_id                                            0
# last_searched                                    13452
# last_scraped                                         0
# name                                                38
# description                                       8066
# neighborhood_overview                           215920
# picture_url                                         86
# host_id                                              0
# host_url                                             0
# host_name                                          972
# host_since                                         972
# host_location                                   123279
# host_about                                      234996
# host_response_time                               53490
# host_response_rate                               53490
# host_acceptance_rate                             44859
# host_is_superhost                               357526
# host_thumbnail_url                                 972
# host_picture_url                                   972
# host_neighbourhood                              381959
# host_listings_count                                972
# host_total_listings_count                          972
# host_verifications                                   0
# host_has_profile_pic                               972
# host_identity_verified                             972
# neighbourhood                                   215920
# latitude                                             0
# longitude                                            0
# property_type                                        0
# room_type                                            0
# accommodates                                         0
# bathrooms                                       440305
# bathrooms_text                                     672
# bedrooms                                         13002
# beds                                              5148
# amenities                                            0
# price                                                0
# minimum_nights                                       0
# maximum_nights                                       0
# minimum_minimum_nights                               3
# maximum_minimum_nights                               3
# minimum_maximum_nights                               3
# maximum_maximum_nights                               3
# minimum_nights_avg_ntm                               3
# maximum_nights_avg_ntm                               3
# calendar_updated                                440305
# has_availability                                     0
# availability_30                                      0
# availability_60                                      0
# availability_90                                      0
# availability_365                                     0
# calendar_last_scraped                                0
# number_of_reviews                                    0
# number_of_reviews_ltm                                0
# number_of_reviews_l30d                               0
# first_review                                    116478
# last_review                                     116478
# review_scores_rating                            116478
# review_scores_accuracy                          119081
# review_scores_cleanliness                       119060
# review_scores_checkin                           119146
# review_scores_communication                     119105
# review_scores_location                          119158
# review_scores_value                             119166
# requires_license                                440305
# license                                         392389
# instant_bookable                                     0
# calculated_host_listings_count                       0
# calculated_host_listings_count_entire_homes          0
# calculated_host_listings_count_private_rooms         0
# calculated_host_listings_count_shared_rooms          0
# region_id                                            0
# region_name                                          0
# region_parent_id                                     0
# region_parent_name                                   0
# region_parent_parent_id                              0
# region_parent_parent_name                            0
# reviews_per_month                               116478
# dtype: int64

# %%
print("Total Number of Missing Values :")
df.isna().sum().sum()
# Out:
# Total Number of Missing Values :
# 4623629

# %% [markdown]
# ### **3.2 Dropping Columns with Missing Values for every Listing**

# %%
# Creating a List of Columns with Missing Values Corresponding to Every Listing
cols=list()
col_names=list(df.columns)
for i in col_names:
  if df[i].isna().sum()==df.shape[0]:
    cols.append(i)
cols
# Out:
# ['bathrooms', 'calendar_updated', 'requires_license']

# %%
df=df.drop(cols,axis=1)

# %% [markdown]
# ### **3.3 Dropping Columns Irrelevant to the Analysis / Columns with Redundant Information**

# %%
df=df.drop(['host_thumbnail_url','host_picture_url','host_neighbourhood','neighbourhood','calendar_last_scraped','host_response_time', 'host_response_rate',
       'host_acceptance_rate','first_review', 'last_review', 'review_scores_accuracy',
       'review_scores_cleanliness', 'review_scores_checkin',
       'review_scores_communication', 'review_scores_location',
       'review_scores_value','calendar_last_scraped','bathrooms_text', 'amenities','host_listings_count',
       'host_total_listings_count','host_verifications',
       'host_has_profile_pic','region_parent_id','host_is_superhost','region_id','listing_url', 'scrape_id', 'last_searched', 'last_scraped',
       'name', 'description', 'neighborhood_overview', 'picture_url','host_url','host_about','has_availability', 'availability_30',
       'availability_60', 'availability_90', 'availability_365','minimum_minimum_nights',
       'maximum_minimum_nights', 'minimum_maximum_nights',
       'maximum_maximum_nights', 'minimum_nights_avg_ntm',
       'maximum_nights_avg_ntm'],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440305 entries, 0 to 440304
# Data columns (total 31 columns):
#  #   Column                                        Non-Null Count   Dtype
# ---  ------                                        --------------   -----
#  0   id                                            440305 non-null  int64
#  1   host_id                                       440305 non-null  int64
#  2   host_name                                     439333 non-null  object
#  3   host_since                                    439333 non-null  object
#  4   host_location                                 317026 non-null  object
#  5   host_identity_verified                        439333 non-null  object
#  6   latitude                                      440305 non-null  float64
#  7   longitude                                     440305 non-null  float64
#  8   property_type                                 440305 non-null  object
#  9   room_type                                     440305 non-null  object
#  10  accommodates                                  440305 non-null  int64
#  11  bedrooms                                      427303 non-null  float64
#  12  beds                                          435157 non-null  float64
#  13  price                                         440305 non-null  object
#  14  minimum_nights                                440305 non-null  int64
#  15  maximum_nights                                440305 non-null  int64
#  16  number_of_reviews                             440305 non-null  int64
#  17  number_of_reviews_ltm                         440305 non-null  int64
#  18  number_of_reviews_l30d                        440305 non-null  int64
#  19  review_scores_rating                          323827 non-null  float64
#  20  license                                       47916 non-null   object
#  21  instant_bookable                              440305 non-null  object
#  22  calculated_host_listings_count                440305 non-null  int64
#  23  calculated_host_listings_count_entire_homes   440305 non-null  int64
#  24  calculated_host_listings_count_private_rooms  440305 non-null  int64
#  25  calculated_host_listings_count_shared_rooms   440305 non-null  int64
#  26  region_name                                   440305 non-null  object
#  27  region_parent_name                            440305 non-null  object
#  28  region_parent_parent_id                       440305 non-null  int64
#  29  region_parent_parent_name                     440305 non-null  object
#  30  reviews_per_month                             323827 non-null  float64
# dtypes: float64(6), int64(13), object(12)
# memory usage: 104.1+ MB

# %% [markdown]
# ### **3.4 Imputing Missing Values for 'Beds' & 'Bedrooms' columns with respective Median Values**

# %%
df['beds']=df['beds'].fillna(df['beds'].median())

# %%
df['bedrooms']=df['bedrooms'].fillna(df['bedrooms'].median())

# %% [markdown]
# ## **4. Feature Engineering**

# %% [markdown]
# ### **4.1 Adding variable to check if a listing has a license or no (If Licensed then 1 , else 0)**

# %%
df['with_license']=np.where(df['license'].isna(),0,1)

# %%
df=df.drop(['license'],axis=1)

# %% [markdown]
# ### **4.2 Adding variable to check if a listing is a STR or a LTR)**

# %%
df['STR_vs_LTR']=np.where(df['minimum_nights']<30,'STR','LTR')

# %%
df['STR_vs_LTR'].value_counts()
# Out:
# STR    437294
# LTR      3011
# Name: STR_vs_LTR, dtype: int64

# %% [markdown]
# ### **4.3 Adding New Columns 'estimated_booking_ltm', 'estimated_nights_ltm' & 'estimated_revenue_ltm' which represent the number of bookings, number of nights booked & revenue generated respectively for the last 12 months '**

# %%
review_rate=0.5
maximum_occupancy=255
average_nights_stay=3
df['price']=df['price'].str.lstrip('$').str.replace(',','')
df['price']=pd.to_numeric(df['price'])
df['estimated_booking_ltm']=round(df['number_of_reviews_ltm']/review_rate).astype(int)
df['estimated_nights_ltm'] = round(np.minimum(df['estimated_booking_ltm'] * (np.maximum(df['minimum_nights'], average_nights_stay)),maximum_occupancy))
df['estimated_revenue_ltm'] = round(df['estimated_nights_ltm'] * df['price'])

# %% [markdown]
# ### **4.4 Adding a New Column 'Frequency_of_renting' which shows how frequently a listing is being rented out**

# %%
df.loc[df['estimated_nights_ltm']<=30, 'Frequency_of_renting'] = 'occasionally rented'
df.loc[((df['estimated_nights_ltm']>30) & (df['estimated_nights_ltm']<=90)) , 'Frequency_of_renting'] = 'semi_regularly rented'
df.loc[df['estimated_nights_ltm']>90, 'Frequency_of_renting'] = 'rented full time'

# %% [markdown]
# ### **4.5 Adding a New Column 'Commercial Nature' with 3 Categories for the listings : 'Home Sharing', 'Semi-Commercial' & 'Commercial'**

# %% [markdown]
# **1. Home Sharing**

# %%
df.loc[(df['room_type']=='Shared room') & (df['calculated_host_listings_count_shared_rooms']==1),'Commercial_Nature']='Home Sharing'
df.loc[(df['room_type']=='Shared room') & (df['calculated_host_listings_count_shared_rooms']>1) & (df['beds']<=3),'Commercial_Nature']='Home Sharing'
df.loc[(df['room_type']=='Private room') & (df['calculated_host_listings_count_private_rooms']<=3),'Commercial_Nature']='Home Sharing'
df.loc[(df['room_type']=='Entire home/apt') & (df['calculated_host_listings_count_entire_homes']==1) & (df['Frequency_of_renting']=='occasionally rented'),'Commercial_Nature']= 'Home Sharing'

# %% [markdown]
# **2. Semi-commercial**

# %%
df.loc[(df['room_type']=='Shared room') & (df['calculated_host_listings_count_shared_rooms']>1) & (df['beds']>3),'Commercial_Nature']='Semi-Commercial'
df.loc[(df['room_type']=='Private room') & (df['calculated_host_listings_count_private_rooms']>3) & (df['calculated_host_listings_count_private_rooms']<=6),'Commercial_Nature']='Semi-Commercial'
df.loc[(df['room_type']=='Entire home/apt') & (df['calculated_host_listings_count_entire_homes']==1) & (df['Frequency_of_renting']=='semi_regularly rented'),'Commercial_Nature']= 'Semi-Commercial'

# %% [markdown]
# **3. Commercial**

# %%
df.loc[(df['room_type']=='Hotel room'),'Commercial_Nature'] ='Commercial'
df.loc[(df['room_type']=='Entire home/apt') & (df['calculated_host_listings_count_entire_homes']>1),'Commercial_Nature'] ='Commercial'
df.loc[(df['room_type']=='Entire home/apt') & (df['calculated_host_listings_count_entire_homes']==1) & (df['Frequency_of_renting']=='rented full time'),'Commercial_Nature']= 'Commercial'
df.loc[(df['room_type']=='Private room') & (df['calculated_host_listings_count_private_rooms']>6),'Commercial_Nature']='Commercial'

# %% [markdown]
# * **Number of Listings Based on Commercial Nature**

# %%
df['Commercial_Nature'].value_counts()
# Out:
# Commercial         243128
# Home Sharing       151427
# Semi-Commercial     45750
# Name: Commercial_Nature, dtype: int64

# %% [markdown]
# ## **5. Renaming Geographical Hierarchies**

# %%
df_final=df.copy()
df_final.columns
# Out:
# Index(['id', 'host_id', 'host_name', 'host_since', 'host_location',
#        'host_identity_verified', 'latitude', 'longitude', 'property_type',
#        'room_type', 'accommodates', 'bedrooms', 'beds', 'price',
#        'minimum_nights', 'maximum_nights', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d',
#        'review_scores_rating', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'region_name',
#        'region_parent_name', 'region_parent_parent_id',
#        'region_parent_parent_name', 'reviews_per_month', 'with_license',
#        'STR_vs_LTR', 'estimated_booking_ltm', 'estimated_nights_ltm',
#        'estimated_revenue_ltm', 'Frequency_of_renting', 'Commercial_Nature'],
#       dtype='object')

# %%
df_final = df_final.rename(columns={'region_parent_parent_name': 'Region/State','region_parent_name': 'Province/County', 'region_name': 'City'})

# %%
df_final.columns
# Out:
# Index(['id', 'host_id', 'host_name', 'host_since', 'host_location',
#        'host_identity_verified', 'latitude', 'longitude', 'property_type',
#        'room_type', 'accommodates', 'bedrooms', 'beds', 'price',
#        'minimum_nights', 'maximum_nights', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d',
#        'review_scores_rating', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'City',
#        'Province/County', 'region_parent_parent_id', 'Region/State',
#        'reviews_per_month', 'with_license', 'STR_vs_LTR',
#        'estimated_booking_ltm', 'estimated_nights_ltm',
#        'estimated_revenue_ltm', 'Frequency_of_renting', 'Commercial_Nature'],
#       dtype='object')

# %% [markdown]
# ## **6. Adding 'Licensed_5' & 'Licensed_10' variables to show which listings are licensed (based on 5% & 10% Thresholds for Licensing Requirements)**

# %%
df_c_1=pd.DataFrame(df_final.groupby(['Region/State','City']).with_license.sum())

# %%
df_c_2=pd.DataFrame(df_final.groupby(['Region/State','City']).id.count())

# %%
df_c_3=pd.DataFrame(df_c_1.values/df_c_2.values)

# %%
df_c_3.index=df_c_2.index
df_c_3.columns=['Percentage_Licensed']

# %%
df_c_3[df_c_3['Percentage_Licensed']>0.05].shape
# Out:
# (2830, 1)

# %%
df_c_4=df_c_3.copy()
df_c_4['requires_license_5']=np.where(df_c_4['Percentage_Licensed']>=0.05,1,0)
df_c_4['requires_license_10']=np.where(df_c_4['Percentage_Licensed']>=0.1,1,0)

# %%
df_c_4.reset_index(inplace=True)

# %%
df_c_4.head()
# Out:
#   Region/State            City  Percentage_Licensed  requires_license_5  \
# 0      Abruzzo      Abbateggio             0.000000                   0
# 1      Abruzzo         Acciano             0.000000                   0
# 2      Abruzzo          Aielli             0.000000                   0
# 3      Abruzzo          Alanno             0.000000                   0
# 4      Abruzzo  Alba Adriatica             0.089005                   1
#
#    requires_license_10
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
df_fin=df_final.set_index(['Region/State','City']).join(df_c_4.set_index(['Region/State','City']))

# %%
df_fin.reset_index(inplace=True)

# %%
df_fin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440305 entries, 0 to 440304
# Data columns (total 40 columns):
#  #   Column                                        Non-Null Count   Dtype
# ---  ------                                        --------------   -----
#  0   Region/State                                  440305 non-null  object
#  1   City                                          440305 non-null  object
#  2   id                                            440305 non-null  int64
#  3   host_id                                       440305 non-null  int64
#  4   host_name                                     439333 non-null  object
#  5   host_since                                    439333 non-null  object
#  6   host_location                                 317026 non-null  object
#  7   host_identity_verified                        439333 non-null  object
#  8   latitude                                      440305 non-null  float64
#  9   longitude                                     440305 non-null  float64
#  10  property_type                                 440305 non-null  object
#  11  room_type                                     440305 non-null  object
#  12  accommodates                                  440305 non-null  int64
#  13  bedrooms                                      440305 non-null  float64
#  14  beds                                          440305 non-null  float64
#  15  price                                         440305 non-null  float64
#  16  minimum_nights                                440305 non-null  int64
#  17  maximum_nights                                440305 non-null  int64
#  18  number_of_reviews                             440305 non-null  int64
#  19  number_of_reviews_ltm                         440305 non-null  int64
#  20  number_of_reviews_l30d                        440305 non-null  int64
#  21  review_scores_rating                          323827 non-null  float64
#  22  instant_bookable                              440305 non-null  object
#  23  calculated_host_listings_count                440305 non-null  int64
#  24  calculated_host_listings_count_entire_homes   440305 non-null  int64
#  25  calculated_host_listings_count_private_rooms  440305 non-null  int64
#  26  calculated_host_listings_count_shared_rooms   440305 non-null  int64
#  27  Province/County                               440305 non-null  object
#  28  region_parent_parent_id                       440305 non-null  int64
#  29  reviews_per_month                             323827 non-null  float64
#  30  with_license                                  440305 non-null  int64
#  31  STR_vs_LTR                                    440305 non-null  object
#  32  estimated_booking_ltm                         440305 non-null  int64
#  33  estimated_nights_ltm                          440305 non-null  int64
#  34  estimated_revenue_ltm                         440305 non-null  float64
#  35  Frequency_of_renting                          440305 non-null  object
#  36  Commercial_Nature                             440305 non-null  object
#  37  Percentage_Licensed                           440305 non-null  float64
#  38  requires_license_5                            440305 non-null  int64
#  39  requires_license_10                           440305 non-null  int64
# dtypes: float64(9), int64(18), object(13)
# memory usage: 134.4+ MB

# %%
# For 5% Threshold
df_fin.loc[(df_fin['with_license']==1),'licensed_5']="Licensed"
df_fin.loc[(df_fin['with_license']==0) & (df_fin['requires_license_5']==0),'licensed_5']="Exempt"
df_fin.loc[(df_fin['with_license']==0) & (df_fin['requires_license_5']==1),'licensed_5']="Unlicensed"

# %%
# For 10% Threshold
df_fin.loc[(df_fin['with_license']==1),'licensed_10']="Licensed"
df_fin.loc[(df_fin['with_license']==0) & (df_fin['requires_license_10']==0),'licensed_10']="Exempt"
df_fin.loc[(df_fin['with_license']==0) & (df_fin['requires_license_10']==1),'licensed_10']="Unlicensed"

# %%
df_fin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440305 entries, 0 to 440304
# Data columns (total 42 columns):
#  #   Column                                        Non-Null Count   Dtype
# ---  ------                                        --------------   -----
#  0   Region/State                                  440305 non-null  object
#  1   City                                          440305 non-null  object
#  2   id                                            440305 non-null  int64
#  3   host_id                                       440305 non-null  int64
#  4   host_name                                     439333 non-null  object
#  5   host_since                                    439333 non-null  object
#  6   host_location                                 317026 non-null  object
#  7   host_identity_verified                        439333 non-null  object
#  8   latitude                                      440305 non-null  float64
#  9   longitude                                     440305 non-null  float64
#  10  property_type                                 440305 non-null  object
#  11  room_type                                     440305 non-null  object
#  12  accommodates                                  440305 non-null  int64
#  13  bedrooms                                      440305 non-null  float64
#  14  beds                                          440305 non-null  float64
#  15  price                                         440305 non-null  float64
#  16  minimum_nights                                440305 non-null  int64
#  17  maximum_nights                                440305 non-null  int64
#  18  number_of_reviews                             440305 non-null  int64
#  19  number_of_reviews_ltm                         440305 non-null  int64
#  20  number_of_reviews_l30d                        440305 non-null  int64
#  21  review_scores_rating                          323827 non-null  float64
#  22  instant_bookable                              440305 non-null  object
#  23  calculated_host_listings_count                440305 non-null  int64
#  24  calculated_host_listings_count_entire_homes   440305 non-null  int64
#  25  calculated_host_listings_count_private_rooms  440305 non-null  int64
#  26  calculated_host_listings_count_shared_rooms   440305 non-null  int64
#  27  Province/County                               440305 non-null  object
#  28  region_parent_parent_id                       440305 non-null  int64
#  29  reviews_per_month                             323827 non-null  float64
#  30  with_license                                  440305 non-null  int64
#  31  STR_vs_LTR                                    440305 non-null  object
#  32  estimated_booking_ltm                         440305 non-null  int64
#  33  estimated_nights_ltm                          440305 non-null  int64
#  34  estimated_revenue_ltm                         440305 non-null  float64
#  35  Frequency_of_renting                          440305 non-null  object
#  36  Commercial_Nature                             440305 non-null  object
#  37  Percentage_Licensed                           440305 non-null  float64
#  38  requires_license_5                            440305 non-null  int64
#  39  requires_license_10                           440305 non-null  int64
#  40  licensed_5                                    440305 non-null  object
#  41  licensed_10                                   440305 non-null  object
# dtypes: float64(9), int64(18), object(15)
# memory usage: 141.1+ MB

# %% [markdown]
# ### **6.1 Adding a New Column 'Country' to the Dataset**

# %%
df_fin['Country']="Italy"

# %%
df_fin.head()
# Out:
#   Region/State        City        id    host_id            host_name  \
# 0      Abruzzo  Abbateggio  50410419  262193532               Typney
# 1      Abruzzo  Abbateggio  37902266   70984271                Noemi
# 2      Abruzzo  Abbateggio  29821070  109957923  Isabelle - BELVILLA
# 3      Abruzzo  Abbateggio  50410346  262193532               Typney
# 4      Abruzzo  Abbateggio  52392818  424085954             Emanuele
#
#    host_since        host_location host_identity_verified   latitude  \
# 0  2019-05-16        Ostuni, Italy                      t  42.213879
# 1  2016-05-08    Abbateggio, Italy                      t  42.212420
# 2  2017-01-05  Zürich, Switzerland                      t  42.215560
# 3  2019-05-16        Ostuni, Italy                      t  42.213880
# 4  2021-09-22                  NaN                      t  42.213590
#
#    longitude                      property_type        room_type  \
# 0  14.001847                 Entire rental unit  Entire home/apt
# 1  14.017850              Private room in villa     Private room
# 2  14.009250                        Entire home  Entire home/apt
# 3  14.001850                 Entire rental unit  Entire home/apt
# 4  13.996630  Private room in bed and breakfast     Private room
#
#    accommodates  bedrooms  beds  price  minimum_nights  maximum_nights  \
# 0             3       1.0   2.0  101.0               1            1125
# 1             2       1.0   1.0   46.0               2              30
# 2             2       1.0   2.0   40.0               1              28
# 3             4       1.0   2.0  159.0               1            1125
# 4             7       2.0   5.0   30.0               1            1125
#
#    number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                  2                      2                       0
# 1                  0                      0                       0
# 2                  8                      5                       0
# 3                  6                      4                       0
# 4                  1                      1                       0
#
#    review_scores_rating instant_bookable  calculated_host_listings_count  \
# 0                  2.50                t                             128
# 1                   NaN                f                               3
# 2                  4.43                t                             370
# 3                  4.50                t                             128
# 4                  5.00                f                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                          103
# 1                                            1
# 2                                          370
# 3                                          103
# 4                                            0
#
#    calculated_host_listings_count_private_rooms  \
# 0                                            25
# 1                                             2
# 2                                             0
# 3                                            25
# 4                                             1
#
#    calculated_host_listings_count_shared_rooms Province/County  \
# 0                                            0         Pescara
# 1                                            0         Pescara
# 2                                            0         Pescara
# 3                                            0         Pescara
# 4                                            0         Pescara
#
#    region_parent_parent_id  reviews_per_month  with_license STR_vs_LTR  \
# 0                       13               0.18             0        STR
# 1                       13                NaN             0        STR
# 2                       13               0.21             0        STR
# 3                       13               0.45             0        STR
# 4                       13               0.12             0        STR
#
#    estimated_booking_ltm  estimated_nights_ltm  estimated_revenue_ltm  \
# 0                      4                    12                 1212.0
# 1                      0                     0                    0.0
# 2                     10                    30                 1200.0
# 3                      8                    24                 3816.0
# 4                      2                     6                  180.0
#
#   Frequency_of_renting Commercial_Nature  Percentage_Licensed  \
# 0  occasionally rented        Commercial                  0.0
# 1  occasionally rented      Home Sharing                  0.0
# 2  occasionally rented        Commercial                  0.0
# 3  occasionally rented        Commercial                  0.0
# 4  occasionally rented      Home Sharing                  0.0
#
#    requires_license_5  requires_license_10 licensed_5 licensed_10 Country
# 0                   0                    0     Exempt      Exempt   Italy
# 1                   0                    0     Exempt      Exempt   Italy
# 2                   0                    0     Exempt      Exempt   Italy
# 3                   0                    0     Exempt      Exempt   Italy
# 4                   0                    0     Exempt      Exempt   Italy

# %%
df_fin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440305 entries, 0 to 440304
# Data columns (total 43 columns):
#  #   Column                                        Non-Null Count   Dtype
# ---  ------                                        --------------   -----
#  0   Region/State                                  440305 non-null  object
#  1   City                                          440305 non-null  object
#  2   id                                            440305 non-null  int64
#  3   host_id                                       440305 non-null  int64
#  4   host_name                                     439333 non-null  object
#  5   host_since                                    439333 non-null  object
#  6   host_location                                 317026 non-null  object
#  7   host_identity_verified                        439333 non-null  object
#  8   latitude                                      440305 non-null  float64
#  9   longitude                                     440305 non-null  float64
#  10  property_type                                 440305 non-null  object
#  11  room_type                                     440305 non-null  object
#  12  accommodates                                  440305 non-null  int64
#  13  bedrooms                                      440305 non-null  float64
#  14  beds                                          440305 non-null  float64
#  15  price                                         440305 non-null  float64
#  16  minimum_nights                                440305 non-null  int64
#  17  maximum_nights                                440305 non-null  int64
#  18  number_of_reviews                             440305 non-null  int64
#  19  number_of_reviews_ltm                         440305 non-null  int64
#  20  number_of_reviews_l30d                        440305 non-null  int64
#  21  review_scores_rating                          323827 non-null  float64
#  22  instant_bookable                              440305 non-null  object
#  23  calculated_host_listings_count                440305 non-null  int64
#  24  calculated_host_listings_count_entire_homes   440305 non-null  int64
#  25  calculated_host_listings_count_private_rooms  440305 non-null  int64
#  26  calculated_host_listings_count_shared_rooms   440305 non-null  int64
#  27  Province/County                               440305 non-null  object
#  28  region_parent_parent_id                       440305 non-null  int64
#  29  reviews_per_month                             323827 non-null  float64
#  30  with_license                                  440305 non-null  int64
#  31  STR_vs_LTR                                    440305 non-null  object
#  32  estimated_booking_ltm                         440305 non-null  int64
#  33  estimated_nights_ltm                          440305 non-null  int64
#  34  estimated_revenue_ltm                         440305 non-null  float64
#  35  Frequency_of_renting                          440305 non-null  object
#  36  Commercial_Nature                             440305 non-null  object
#  37  Percentage_Licensed                           440305 non-null  float64
#  38  requires_license_5                            440305 non-null  int64
#  39  requires_license_10                           440305 non-null  int64
#  40  licensed_5                                    440305 non-null  object
#  41  licensed_10                                   440305 non-null  object
#  42  Country                                       440305 non-null  object
# dtypes: float64(9), int64(18), object(16)
# memory usage: 144.4+ MB

# %% [markdown]
# * **Exporting the Cleaned .csv File**

# %%
df_fin.to_csv('/content/drive/MyDrive/Advanced Business Analytics and Project Management/Final Files/Italy.csv')
